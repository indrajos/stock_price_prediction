# %%
import pandas as pd
import numpy as np
import plotly.graph_objs as go
import plotly.offline as py
import plotly.express as px

# %%
stock_w = pd.read_csv(r'c:\\Users\\SN\\Desktop\\stock_predict\\stock_price_prediction\\BA.csv')
display(stock_w)
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2000-01-01   41.437500   44.875000   39.750000   44.312500   28.602909
# 1     2000-01-08   44.312500   44.500000   42.000000   44.000000   28.401178
# 2     2000-01-15   44.000000   48.125000   43.125000   45.687500   29.490440
# 3     2000-01-22   45.687500   46.875000   43.625000   44.625000   28.804600
# 4     2000-01-29   44.562500   45.187500   42.562500   44.000000   28.401178
# ...          ...         ...         ...         ...         ...         ...
# 1167  2022-05-14  127.050003  132.830002  117.080002  120.699997  120.699997
# 1168  2022-05-21  121.699997  132.229996  117.290001  132.229996  132.229996
# 1169  2022-05-28  131.029999  140.699997  127.010002  139.250000  139.250000
# 1170  2022-06-04  139.990005  142.210007  126.849998  127.000000  127.000000
# 1171  2022-06-11         NaN         NaN         NaN         NaN         NaN
#
#           Volume
# 0     24792500.0
# ...

# %%
trace1 = go.Bar(
    x = stock_w['Date'],
    y = stock_w['Adj Close'],
    name='Influenza',
    marker=dict(color='rgba(16, 112, 2, 0.8)',
                line=dict(color='rgb(0,0,0)', width=1.5)),
     
)

data = [trace1]
layout = dict(
    title='Boeing Adj Close',
    xaxis=dict( 
        ticks='outside', ticklen=5, 
        zeroline=True, linewidth=1, linecolor='black'
        )
    )
fig = go.Figure(data=data, layout=layout)            
py.iplot(fig)

# %%
date_range = stock_w[stock_w["Date"] > "2016-01-01"]
display(date_range)
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 835   2016-01-02  141.380005  141.699997  129.800003  129.990005  116.579399
# 836   2016-01-09  130.850006  132.880005  124.510002  125.629997  112.669189
# 837   2016-01-16  127.059998  127.220001  119.820000  124.610001  111.754425
# 838   2016-01-23  124.599998  128.149994  115.019997  120.129997  107.736595
# 839   2016-01-30  119.639999  124.910004  117.150002  122.559998  109.915916
# ...          ...         ...         ...         ...         ...         ...
# 1167  2022-05-14  127.050003  132.830002  117.080002  120.699997  120.699997
# 1168  2022-05-21  121.699997  132.229996  117.290001  132.229996  132.229996
# 1169  2022-05-28  131.029999  140.699997  127.010002  139.250000  139.250000
# 1170  2022-06-04  139.990005  142.210007  126.849998  127.000000  127.000000
# 1171  2022-06-11         NaN         NaN         NaN         NaN         NaN
#
#           Volume
# 835   26121200.0
# ...

# %%
trace1 = go.Scatter(
    x = date_range['Date'],
    y = date_range['Low'],
    mode='lines+markers',
    name='Low',
    marker=dict(color='rgba(16, 112, 2, 0.8)'),
)
trace2 = go.Scatter(
    x = date_range['Date'],
    y = date_range['High'],
    mode='lines+markers',
    name='High',
    marker=dict(color='rgba(80, 26, 80, 0.8)'),
)
data = [trace1, trace2]
layout = dict(
    title='Boeing 2016-2022',
    xaxis=dict( 
        ticks='outside', ticklen=5, 
        zeroline=True, linewidth=1, linecolor='black'
        ))
fig = dict(data=data, layout=layout)            
py.iplot(fig)
